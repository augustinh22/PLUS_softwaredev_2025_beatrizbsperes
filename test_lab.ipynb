# %%
from matplotlib import pyplot as plt
import numpy as np

# Generate 100 random data points along 3 dimensions
x, y, scale = np.random.randn(3, 100)
fig, ax = plt.subplots()

# Map each onto a scatterplot we'll create with Matplotlib
ax.scatter(x=x, y=y, c=scale, s=np.abs(scale)*500)
ax.set(title="Some random data, created with JupyterLab!")
plt.show()

# %%
import test_test_test as file_python

# %%
file_python.days_of_the_week
# Out:
# 7

# %%
file_python.say_hello("test")
# Out:
# Hello, world! Hello test
# 'test'

# %%
# !dir
# Out:
#  Volume in drive C is Windows
#  Volume Serial Number is 0EB7-C0BB
#
#  Directory of C:\Users\b1041827\repos\PLUS_softwaredev_2025_beatrizbsperes
#
# 24.03.2025  11:56    <DIR>          .
# 24.03.2025  11:56    <DIR>          ..
# 24.03.2025  11:46    <DIR>          .ipynb_checkpoints
# 24.03.2025  10:59               263 amna-favs.md
# 24.03.2025  10:59               175 bruna-tips.md
# 24.03.2025  10:59               377 FromElouannForBea.md
# 24.03.2025  10:59               157 README.md
# 24.03.2025  11:56            84ÿ535 test_lab.ipynb
# 24.03.2025  11:53               150 test_test_test.py
# 24.03.2025  11:54    <DIR>          __pycache__
#                6 File(s)         85ÿ657 bytes
#                4 Dir(s)  341ÿ791ÿ035ÿ392 bytes free
